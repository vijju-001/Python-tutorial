# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#line plot

# %%
x=np.arange(0,10)
y=np.arange(20,30)

# %%
plt.plot(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title('Line plot using plotlib')

plt.show()
